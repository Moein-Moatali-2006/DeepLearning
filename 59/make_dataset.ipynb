# %%
import os
import pydub
import matplotlib.pyplot as plt

# %%
voice_1 = pydub.AudioSegment.from_file("raw_data\Mohamad.ogg")

# %%
voice_1
# Out:
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>

# %%
voice_1.export("Mohamad.wav")
# Out:
# <_io.BufferedRandom name='Mohamad.wav'>

# %%
voice_1 = pydub.AudioSegment.from_file("raw_data\AmirHosein_1.ogg")
voice_2 = pydub.AudioSegment.from_file("raw_data\AmirHosein_2.ogg")

result = voice_1 + voice_2
result.export("data\AmirHosein.ogg")
# Out:
# <_io.BufferedRandom name='data\\AmirHosein.ogg'>

# %%
voice_1 = pydub.AudioSegment.from_file("raw_data\Mona.m4a")
voice_1.export("data/mona.ogg")
# Out:
# <_io.BufferedRandom name='data/mona.ogg'>

# %%
voice_1 = pydub.AudioSegment.from_file("data\Javad.ogg")

voice_2 = voice_1.get_array_of_samples()
print(type(voice_2))

plt.figure(figsize=(20,2))
plt.plot(voice_2)
plt.show()
# Out:
# <class 'array.array'>

# %%
parts = pydub.silence.split_on_silence(voice_1, min_silence_len=1000, silence_thresh=-45)
# parts = pydub.silence.split_on_silence(voice_1)
parts

# %%
result = sum(parts)
result.export("Javad.ogg")
# Out:
# <_io.BufferedRandom name='Javad.ogg'>

# %%
files = os.listdir("data")
for file in files:
    audio = pydub.AudioSegment.from_file(os.path.join("data",file))

    audio_array = audio.get_array_of_samples()
    plt.figure(figsize=(20,2))
    plt.plot(audio_array)
    plt.show()

    chunks = pydub.silence.split_on_silence(audio,min_silence_len=2000,silence_thresh=-45)
    results = sum(chunks)
    file_name = file.split(".")[0]
    result.export("wav_data/"+file_name+".wav")
