# %%
# !pip install -q roboflow
# !pip install -q ultralytics

# %%
import cv2
from roboflow import Roboflow
from ultralytics import YOLO

# %%
rf = Roboflow(api_key="zDThXzqJkiGIEb3qrl0t")
project = rf.workspace("sajjad-aemmi").project("persian-license-plate-detection")
version = project.version(7)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Persian-License-Plate-Detection-7 in yolov8:: 100%|██████████| 1952/1952 [00:00<00:00, 3033.68it/s]

# %%
model = YOLO("yolov8n.pt")
model.train(data="/content/Persian-License-Plate-Detection-7/data.yaml", epochs=50, imgsz=640)
# Out:
# Ultralytics 8.3.111 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
model = YOLO("runs/detect/train6/weights/best.pt")

# %%
test1 = cv2.imread("test1.jpg")
test1 = cv2.resize(test1, (640, 640))

results1 = model.predict(test1, save=True, conf=0.5)
results1[0].show()
# Out:
# 0: 640x640 1 License-Plate, 7.5ms
# Speed: 2.8ms preprocess, 7.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# <PIL.Image.Image image mode=RGB size=640x640>

# %%
test2 = cv2.imread("test2.jpg")
test2 = cv2.resize(test2, (640, 640))
results2 = model.predict(test2, save=True, conf=0.5)
results2[0].show()
# Out:
# 0: 640x640 1 License-Plate, 9.7ms
# Speed: 2.9ms preprocess, 9.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# <PIL.Image.Image image mode=RGB size=640x640>
